# %%
import pandas as pd

# %%
season_records = pd.DataFrame()

url = 'https://www.pro-football-reference.com/teams/cle/index.htm'
data = pd.read_html(url)

df = data[0]
df
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0 Unnamed: 2_level_0  \
#                  Year                 Lg                 Tm
# 0                2022                NFL   Cleveland Browns
# 1                2021                NFL   Cleveland Browns
# 2                2020                NFL  Cleveland Browns*
# 3                2019                NFL   Cleveland Browns
# 4                2018                NFL   Cleveland Browns
# ..                ...                ...                ...
# 73               1950                NFL  Cleveland Browns*
# 74               1949               AAFC  Cleveland Browns*
# 75               1948               AAFC  Cleveland Browns*
# 76               1947               AAFC  Cleveland Browns*
# 77               1946               AAFC  Cleveland Browns*
#
#    Unnamed: 3_level_0 Unnamed: 4_level_0 Unnamed: 5_level_0  \
#                     W                  L                  T
# 0                   7                 10                  0
# ...

# %%
df.MultiIndex.droplevel()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 df.MultiIndex.droplevel()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'MultiIndex'
